# %% [markdown]
# ## Visual Transformers for EO

# %% [markdown]
# import torch

# %%
import torch
from torch import nn
import einops
import numpy as np
from einops.layers.torch import Rearrange

# %%
t = torch.randn(1,3,224,224)

# %%
class PatchEmbedding(nn.Module):
    def __init__(self, in_channels, patch_size, embed_dim):
        super().__init__(self)
        self.in_channels = in_channels
        self.patch_size = patch_size
        self.embed_dim = embed_dim 
        self.proj = nn.Sequential(
            
        )

# %%
import sys
import Path
import os
def lookit_config():
    os.file
# Out:
#   Cell In[1], line 3
#     def lookit_config():
#                         ^
# SyntaxError: incomplete input

# %%
def find_all_files(folder_path):
    all_files = []
    for root, dirs, files in os.walk(folder_path):
        for file in files:
            all_files.append(os.path.join(root, file))
    return all_files

# %%
import os
os.getcwd()
# Out:
# '/root/bigearthnet/BigEarthNet-Models/bigearthnet/explore'

# %%
path_list_config = os.path.join(os.getcwd(),"src/list_config")

# %%
find_all_files(path_list_config)[1]
# Out:
# '/root/bigearthnet/BigEarthNet-Models/bigearthnet/explore/src/list_config/config2.yaml'

# %%
from src.utils.utils import load_config

# %%
tt = find_all_files(path_list_config)[1]

# %%
tt.split("/")[-1:]
# Out:
# ['config2.yaml']
